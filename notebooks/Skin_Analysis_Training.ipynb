# %% [markdown]
# # Facial Skin Analysis Model Training
# This notebook will install dependencies, download a dataset, and train a YOLOv8 model for facial skin condition detection.

# %% [markdown]
# ## Step 1: Install Dependencies

# %%
# !pip install ultralytics roboflow -q
import ultralytics
ultralytics.checks()

# %% [markdown]
# ## Step 2: Download Dataset
# You will need a Roboflow API snippet to download your annotated skin dataset. Replace the placeholder below with your actual snippet from Roboflow Universe.

# %%
from roboflow import Roboflow
print("Upload your dataset snippet from roboflow here.")
# Example:
# rf = Roboflow(api_key="YOUR_API_KEY")
# project = rf.workspace("your-workspace").project("skin-conditions")
# dataset = project.version(1).download("yolov8")

# %% [markdown]
# ## Step 3: Train the YOLOv8 Model
# Train the segmentation model on the dataset for 50 epochs.

# %%
from ultralytics import YOLO

# Load a YOLOv8 Nano segmentation model
model = YOLO('yolov8n-seg.pt')

# Train the model. Be sure to point `data` to your downloaded data.yaml file.
# results = model.train(data='dataset/data.yaml', epochs=50, imgsz=640)
print("Uncomment the model.train() line above once your dataset is downloaded.")

# %% [markdown]
# ## Step 4: Export and Download Model
# Zip the trained model weights so you can download them to your local machine and use them in the recommendation engine.

# %%
import shutil
from google.colab import files

# zip the runs directory which contains the trained model (best.pt)
# shutil.make_archive('trained_model', 'zip', 'runs/segment/train')
# files.download('trained_model.zip')
